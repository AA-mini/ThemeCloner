# %% [markdown]
# Amir's comments:
#
# ignore the # %% comments, its where I have my code block by block in my notebook, but stuck it together in one patch for you so its easier to run and read..(but impossible to debug ! =)

# %%
# pull_stocks.py
# pulls Russell 1000 ex-SP500 monthly returns from WRDS CRSP
# also grabs the 5 theme ETF returns via yfinance as the "seeds"
#
# two ways to get the CRSP data:
#   1. WRDS python API  (easier, runs automatically)
#   2. manual download from WRDS web interface (fallback)
#
# output: russell1000_exsp500_returns.csv, etf_theme_returns.csv

# %%

import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")


# %%

#___ method 1: WRDS python API ___

"""
requires the wrds package:
    pip install wrds

credentials get saved after the first login so only need to enter once
"""

def pull_via_api():
    try:
        import wrds
        print("connecting to WRDS...")
        db = wrds.Connection(wrds_username="aa9994")
        print("connected\n")

        # get SP500 constituents so we can exclude them later
        # CRSP has a table tracking index membership by month
        print("pulling S&P 500 constituent list...")
        sp500_query = """
            select permno, start, ending
            from crsp.msp500list
        """
        sp500 = db.raw_sql(sp500_query)
        sp500["start"]  = pd.to_datetime(sp500["start"])
        sp500["ending"] = pd.to_datetime(sp500["ending"])
        print(f"  got {len(sp500)} SP500 constituent records")

        # pull monthly returns
        """
        Russell 1000 ex-SP500 is approximately stocks ranked 500-1000
        by market cap. We don't have Russell constituent data directly
        in CRSP so we proxy using market cap rank each month.
        
        filters applied here:
          shrcd 10/11  = ordinary common shares, US incorporated
          exchcd 1/2/3 = NYSE, AMEX, NASDAQ
          price >= $5  = avoid penny stocks messing up market cap calc
          2000 onwards = theme investing is a recent phenomenon
        """
        print("pulling monthly returns from CRSP (slow, ~1 min)...")
        ret_query = """
            select a.permno, a.date, a.ret, a.prc, a.shrout, 
                   b.ticker, b.comnam, b.siccd, b.exchcd
            from crsp.msf as a
            left join crsp.msenames as b
                on a.permno = b.permno
                and b.namedt <= a.date
                and a.date <= b.nameendt
            where a.date between '2000-01-01' and '2024-12-31'
                and b.shrcd in (10, 11)
                and b.exchcd in (1, 2, 3)
                and a.ret is not null
                and abs(a.prc) >= 5
        """
        raw = db.raw_sql(ret_query, date_cols=["date"])
        print(f"  pulled {len(raw):,} rows")

        db.close()
        return raw, sp500

    except ImportError:
        print("wrds not installed -- run: pip install wrds")
        return None, None
    except Exception as e:
        print(f"API failed: {e}")
        return None, None


# %%

def process_raw(raw, sp500):
    """filter down to Russell 1000 ex-SP500 proxy"""

    print("processing...")

    raw["mktcap"] = raw["prc"].abs() * raw["shrout"]  # shrout is in thousands
    raw["date"] = pd.to_datetime(raw["date"])
    raw["ym"]   = raw["date"].dt.to_period("M")

    # build a dict of {month -> set of SP500 permnos} for fast lookup
    print("  building SP500 membership lookup by month...")
    sp500_by_month = {}
    for _, row in sp500.iterrows():
        months = pd.period_range(
            start=row["start"].to_period("M"),
            end=row["ending"].to_period("M"),
            freq="M"
        )
        for m in months:
            if m not in sp500_by_month:
                sp500_by_month[m] = set()
            sp500_by_month[m].add(row["permno"])

    raw["in_sp500"] = raw.apply(
        lambda r: r["permno"] in sp500_by_month.get(r["ym"], set()),
        axis=1
    )

    # rank all stocks by market cap each month
    print("  ranking by mktcap each month...")
    raw["mktcap_rank"] = raw.groupby("ym")["mktcap"].rank(
        ascending=False, method="first"
    )

    # keep top 1000 by mktcap, not in SP500, and above $500m floor
    # $500m minimum cuts out very small stocks that sneak into the top 1000
    # in thin months
    universe = raw[
        (raw["mktcap_rank"] <= 1000) &
        (~raw["in_sp500"]) &
        (raw["mktcap"] >= 500_000)
    ].copy()

    print(f"  {universe['permno'].nunique():,} unique stocks in universe")
    print(f"  {len(universe):,} total monthly obs")

    universe = universe[universe["ret"].between(-0.99, 10)]
    universe = universe.dropna(subset=["ret"])

    return universe


# %%

#___ method 2: manual WRDS web query ___

"""
for future reference, if the API fails the same data can be pulled
manually from the WRDS web interface:
    https://wrds-www.wharton.upenn.edu/

    Get Data -> CRSP -> Stock/Security Files -> Monthly Stock File
    date range: 2000-01 to 2024-12, leave company field blank
    
    variables needed: PERMNO, date, RET, PRC, SHROUT
    screening: SHRCD = 10, 11 / EXCHCD = 1, 2, 3
    
    also need a separate names query:
    Get Data -> CRSP -> Stock/Security Files -> Names
    variables: PERMNO, TICKER, COMNAM, SICCD, NAMEDT, NAMEENDT
    
    save both as crsp_monthly_returns.csv and crsp_names.csv,
    then flip USE_MANUAL = True at the bottom and rerun
"""

def manual_instructions():
    print("see docstring above for manual download steps")
    print("set USE_MANUAL = True after downloading the files")


def load_manual():
    import os
    ret_file  = "crsp_monthly_returns.csv"
    name_file = "crsp_names.csv"

    if not os.path.exists(ret_file):
        print(f"can't find {ret_file}")
        manual_instructions()
        return None, None

    print(f"loading {ret_file}...")
    raw = pd.read_csv(ret_file, low_memory=False)
    raw.columns = raw.columns.str.lower()
    raw["date"] = pd.to_datetime(raw["date"].astype(str), format="%Y%m%d", errors="coerce")
    raw = raw.rename(columns={"permno":"permno","ret":"ret","prc":"prc","shrout":"shrout"})

    if os.path.exists(name_file):
        print(f"merging names from {name_file}...")
        names = pd.read_csv(name_file, low_memory=False)
        names.columns = names.columns.str.lower()
        names["namedt"]   = pd.to_datetime(names["namedt"].astype(str), format="%Y%m%d", errors="coerce")
        names["nameendt"] = pd.to_datetime(names["nameendt"].astype(str), format="%Y%m%d", errors="coerce")
        raw = raw.merge(
            names[["permno","ticker","comnam","siccd","exchcd","namedt","nameendt"]],
            on="permno", how="left"
        )
        raw = raw[(raw["namedt"] <= raw["date"]) & (raw["date"] <= raw["nameendt"])]

    return raw, None


# %%

#___ ETF theme seeds (always free via yfinance) ___

def pull_etf_returns():
    """
    Pull monthly returns for the 5 theme ETFs.
    These serve as "seeds" -- we find mid-cap stocks that match
    each ETF's factor exposure profile.
    """
    try:
        import yfinance as yf
    except ImportError:
        print("need yfinance: pip install yfinance")
        return None

    themes = {
        "DTCR": "AI Infrastructure",
        "NUKZ": "Energy Independence",
        "HOMZ": "US Housing & Consumer",
        "AGNG": "Bio-Economy & Longevity",
        "FITE": "Defence & Security",
    }

    print("pulling ETF returns from yfinance...")
    frames = []
    for ticker, theme in themes.items():
        try:
            tk   = yf.Ticker(ticker)
            hist = tk.history(start="2018-01-01", end="2024-12-31",
                              interval="1mo", auto_adjust=True)
            if len(hist) == 0:
                print(f"  {ticker}: no data returned")
                continue
            ret = hist["Close"].pct_change().dropna()
            ret.index = ret.index.to_period("M")
            ret.name  = ticker
            frames.append(ret)
            print(f"  {ticker} ({theme}): {len(ret)} months  "
                  f"[{ret.index[0]} - {ret.index[-1]}]")
        except Exception as e:
            print(f"  {ticker}: failed -- {e}")

    if not frames:
        return None

    etf_ret = pd.DataFrame(frames).T
    etf_ret.index.name = "date"
    etf_ret.attrs["themes"] = themes

    etf_ret.to_csv("etf_theme_returns.csv")
    print(f"\nsaved etf_theme_returns.csv  shape: {etf_ret.shape}")
    return etf_ret


# %%

#___ main ___

if __name__ == "__main__":

    USE_MANUAL = False  # flip to True if API fails and you've downloaded manually

    print("step 1: ETF seeds")
    etf_ret = pull_etf_returns()

    print("\nstep 2: Russell 1000 ex-SP500 stocks")

    if USE_MANUAL:
        raw, sp500 = load_manual()
    else:
        raw, sp500 = pull_via_api()

    if raw is None:
        print("no data -- check API connection or set USE_MANUAL = True")

    else:
        if sp500 is not None:
            universe = process_raw(raw, sp500)
        else:
            # manual pull path -- no SP500 table, approximate by mktcap rank
            raw["mktcap"] = raw["prc"].abs() * raw["shrout"]
            raw["ym"] = pd.to_datetime(raw["date"]).dt.to_period("M")
            raw["mktcap_rank"] = raw.groupby("ym")["mktcap"].rank(
                ascending=False, method="first"
            )
            universe = raw[
                (raw["mktcap_rank"].between(500, 1000)) &
                (raw["mktcap"] >= 500_000)
            ].copy()

        universe.to_csv("russell1000_exsp500_returns.csv", index=False)
        print(f"\nsaved russell1000_exsp500_returns.csv")
        print(f"  stocks: {universe['permno'].nunique():,}")
        print(f"  obs: {len(universe):,}")
        print(f"  range: {universe['date'].min().strftime('%Y-%m')} to "
              f"{universe['date'].max().strftime('%Y-%m')}")


# %%

        # quick sanity check -- sector breakdown
        if "siccd" in universe.columns:
            universe["siccd"] = pd.to_numeric(universe["siccd"], errors="coerce")

            def sic_sector(s):
                if pd.isna(s):    return "Unknown"
                s = int(s)
                if s < 1000:      return "Agriculture"
                elif s < 1500:    return "Mining"
                elif s < 1800:    return "Construction"
                elif s < 4000:    return "Manufacturing"
                elif s < 5000:    return "Transport/Utilities"
                elif s < 5200:    return "Wholesale"
                elif s < 6000:    return "Retail"
                elif s < 6500:    return "Finance"
                elif s < 6800:    return "Real Estate"
                elif s < 7300:    return "Services"
                elif s < 8000:    return "Business Services"
                elif s < 9000:    return "Health/Education"
                else:             return "Public Admin"

            universe["sector"] = universe["siccd"].apply(sic_sector)
            counts = (universe.groupby("sector")["permno"]
                      .nunique().sort_values(ascending=False))

            print("\nsector breakdown:")
            for sec, n in counts.items():
                bar = "█" * min(int(n // 5), 40)
                print(f"  {sec:25s} {bar} ({n})")

        print("\ndone -- next: rppca_openAP.py")
# Out:
# step 1: ETF seeds
# pulling ETF returns from yfinance...
#   DTCR (AI Infrastructure): 50 months  [2020-11 - 2024-12]
#   NUKZ (Energy Independence): 11 months  [2024-02 - 2024-12]
#   HOMZ (US Housing & Consumer): 69 months  [2019-04 - 2024-12]
#   AGNG (Bio-Economy & Longevity): 83 months  [2018-02 - 2024-12]
#   FITE (Defence & Security): 83 months  [2018-02 - 2024-12]
#
# saved etf_theme_returns.csv  shape: (83, 5)
#
# step 2: Russell 1000 ex-SP500 stocks
# connecting to WRDS...
# Loading library list...
# Done
# connected
#
# pulling S&P 500 constituent list...
#   got 2064 SP500 constituent records
# pulling monthly returns from CRSP (slow, ~1 min)...
#   pulled 980,879 rows
# processing...
#   building SP500 membership lookup by month...
#   ranking by mktcap each month...
#   3,071 unique stocks in universe
#   163,393 total monthly obs
#
# saved russell1000_exsp500_returns.csv
#   stocks: 3,070
#   obs: 163,391
#   range: 2000-01 to 2024-12
#
# sector breakdown:
#   Manufacturing             ████████████████████████████████████████ (986)
#   Business Services         ████████████████████████████████████████ (508)
#   Public Admin              ████████████████████████████████████████ (360)
#   Finance                   ████████████████████████████████████████ (345)
#   Transport/Utilities       ████████████████████████████████████████ (344)
#   Retail                    ████████████████████████████████████ (181)
#   Health/Education          ███████████████████████████████████ (179)
#   Mining                    ██████████████████████████████████ (171)
#   Real Estate               ███████████████████████ (116)
#   Wholesale                 ███████████████████████ (116)
#   Construction              ████████ (42)
#   Services                  █████ (27)
#   Agriculture               ███ (18)
#
# done -- next: rppca_openAP.py

# %%
# !python rppca_openAP.py
# Out:
# loading OpenAP returns...
#   689 months x 145 anomalies
#   1966-07 to 2023-12
#
# running RP-PCA (gamma=10, K=5)...
# running PCA (gamma=-1, K=5)...
#
# --- factor Sharpe ratios ---
#     factor   RP-PCA SR    PCA SR
# -----------------------------------
#   factor 1       0.214     0.140
#   factor 2       0.646     0.181
#   factor 3       0.496     0.412
#   factor 4       0.549     0.299
#   factor 5       0.476     0.335
#
#   SDF (combined K=5):
#   RP-PCA: 2.976   PCA: 0.651
#   ratio:  4.57x  (paper reports ~2x)
#
# --- factor interpretation (top anomalies by loading) ---
#
#   Factor 1 (SR=0.214):
#     positive loadings: ['IdioVolAHT', 'RealizedVol', 'MaxRet', 'IdioVol3F', 'Mom12m', 'Mom6m', 'MomVol', 'Mom12mOffSeason']
#     negative loadings: ['BetaFP', 'BidAskSpread', 'Beta', 'Price', 'BrandInvest']
#     -> label: Momentum
#
#   Factor 2 (SR=0.646):
#     positive loadings: ['AccrualsBM', 'Frontier', 'MomOffSeason', 'STreversal', 'SP', 'DolVol', 'AssetGrowth', 'BM']
#     negative loadings: ['VarCF', 'BetaFP', 'BookLeverage', 'GrSaleToGrOverhead', 'Mom12m']
#     -> label: Value
#
#   Factor 3 (SR=0.496):
#     positive loadings: ['MomVol', 'Mom12mOffSeason', 'Mom12m', 'FirmAgeMom', 'IntMom', 'Mom6m', 'MomRev', 'IndRetBig']
#     negative loadings: ['IdioVolAHT', 'CashProd', 'IntanCFP', 'Leverage', 'IntanBM']
#     -> label: Momentum
#
#   Factor 4 (SR=0.549):
#     positive loadings: ['STreversal', 'roaq', 'BetaFP', 'cfp', 'SP', 'NetPayoutYield', 'Beta', 'TrendFactor']
#     negative loadings: ['zerotrade12M', 'std_turn', 'zerotrade6M', 'PriceDelayRsq', 'zerotrade1M']
#     -> label: Value
#
#   Factor 5 (SR=0.476):
#     positive loadings: ['STreversal', 'NetDebtPrice', 'MaxRet', 'RD', 'std_turn', 'OperProfRD', 'MomSeason', 'IndRetBig']
#     negative loadings: ['Mom6m', 'MomRev', 'Mom12m', 'Leverage', 'BetaFP']
#     -> label: Momentum
#
# factor labels: {'F1': 'Momentum', 'F2': 'Value', 'F3': 'Momentum', 'F4': 'Value', 'F5': 'Momentum'}
#
# generating figures...
# Figure(1500x1000)
#   saved rppca_openAP_results.png
#
# saved factor_loadings.csv
# saved factor_timeseries.csv
# saved factor_weights.csv
# saved factor_labels.csv
#
# summary:
#   N anomalies : 145
#   T months    : 689
#   RP-PCA SDF SR : 2.976
#   PCA SDF SR    : 0.651
#   ratio         : 4.57x
#
# next step: run theme_engine.py
#
# loading inputs...
#   factor time series: (689, 5)
#   factor labels: {'F1': 'Momentum', 'F2': 'Value', 'F3': 'Momentum', 'F4': 'Value', 'F5': 'Momentum'}
#   ETF returns: (83, 5)  tickers: ['DTCR', 'NLR', 'HOMZ', 'AGNG', 'FITE']
#   loading stock returns (may take a moment)...
#   stock data: 163,391 rows, 3,070 stocks
#
# --- step 1: ETF factor exposures ---
#   DTCR (AI Infrastructure):  38 months  R²=0.452
#     betas: Momentum=-0.061  Value=-0.013  Momentum.1=+0.160  Value.1=+0.349  Momentum.2=+0.226
#   NLR (Energy Independence):  71 months  R²=0.365
#     betas: Momentum=-0.035  Value=+0.005  Momentum.1=+0.035  Value.1=+0.190  Momentum.2=+0.053
#   HOMZ (US Housing & Consumer):  57 months  R²=0.584
#     betas: Momentum=-0.097  Value=-0.013  Momentum.1=+0.128  Value.1=+0.366  Momentum.2=+0.076
#   AGNG (Bio-Economy & Longevity):  71 months  R²=0.537
#     betas: Momentum=-0.069  Value=-0.073  Momentum.1=+0.131  Value.1=+0.198  Momentum.2=+0.007
#   FITE (Defence & Security):  71 months  R²=0.589
#     betas: Momentum=-0.102  Value=-0.083  Momentum.1=+0.124  Value.1=+0.238  Momentum.2=+0.008
#
# ETF beta matrix:
#         Momentum  Value  Momentum.1  Value.1  Momentum.2
# ticker
# DTCR      -0.061 -0.013       0.160    0.349       0.226
# NLR       -0.035  0.005       0.035    0.190       0.053
# HOMZ      -0.097 -0.013       0.128    0.366       0.076
# AGNG      -0.069 -0.073       0.131    0.198       0.007
# FITE      -0.102 -0.083       0.124    0.238       0.008
#
# --- step 2: computing stock factor exposures ---
#   (running rolling OLS for each stock - takes a few minutes)
#   aligned: 288 months x 3070 stocks
#   processing 0/3070...
#   processing 500/3070...
#   processing 1000/3070...
#   processing 1500/3070...
#   processing 2000/3070...
#   processing 2500/3070...
#   processing 3000/3070...
#
#   stocks with sufficient history: 1,344
#   beta matrix shape: (1344, 9)
#
# --- step 3: matching stocks to themes ---
#
#   DTCR — AI Infrastructure:
#   rank    ticker                         company  similarity      R²
#   -----------------------------------------------------------------
#      1      NEOG                     NEOGEN CORP       0.997   0.198
#      2       AGP                 AMERIGROUP CORP       0.996   0.301
#      3         W                     WAYFAIR INC       0.994   0.593
#      4       KNX    KNIGHT SWIFT TRANSPORT HDLGS       0.993   0.362
#      5       KKR                  K K R & CO INC       0.993   0.392
#      6      ROSE           ROSETTA RESOURCES INC       0.992   0.375
#      7       FOX     FOX ENTERTAINMENT GROUP INC       0.992   0.468
#      8      BLDR        BUILDERS FIRSTSOURCE INC       0.991   0.393
#      9       CDW                  C D W CORP NEW       0.991   0.339
#     10       RMD                      RESMED INC       0.990   0.117
#     11       APH               AMPHENOL CORP NEW       0.989   0.496
#     12       SLH             SOLERA HOLDINGS INC       0.989   0.163
#     13      FOXF        FOX FACTORY HOLDING CORP       0.988   0.366
#     14       INT        WORLD FUEL SERVICES CORP       0.988   0.152
#     15       BLD                   TOPBUILD CORP       0.987   0.410
#
#   NLR — Energy Independence:
#   rank    ticker                         company  similarity      R²
#   -----------------------------------------------------------------
#      1      EEFT           EURONET WORLDWIDE INC       0.999   0.176
#      2       EVR                    EVERCORE INC       0.997   0.541
#      3      VSAT                      VIASAT INC       0.991   0.153
#      4       TDW               TIDEWATER INC NEW       0.990   0.282
#      5        OC               OWENS CORNING NEW       0.989   0.447
#      6      ARMK                         ARAMARK       0.988   0.334
#      7       NUS         NU SKIN ENTERPRISES INC       0.986   0.130
#      8       TDS    TELEPHONE & DATA SYSTEMS INC       0.986   0.200
#      9      GNTX                     GENTEX CORP       0.985   0.348
#     10       HGV      HILTON GRAND VACATIONS INC       0.985   0.437
#     11       TGI           TRIUMPH GROUP INC NEW       0.985   0.250
#     12      ELAN        ELANCO ANIMAL HEALTH INC       0.984   0.317
#     13       VVV                   VALVOLINE INC       0.984   0.432
#     14       TLB                     TALBOTS INC       0.984   0.211
#     15      CAKE          CHEESECAKE FACTORY INC       0.983   0.338
#
#   HOMZ — US Housing & Consumer:
#   rank    ticker                         company  similarity      R²
#   -----------------------------------------------------------------
#      1       VVV                   VALVOLINE INC       0.999   0.432
#      2       TDS    TELEPHONE & DATA SYSTEMS INC       0.998   0.200
#      3       DAN                        DANA INC       0.997   0.519
#      4       TEX                  TEREX CORP NEW       0.996   0.484
#      5      STLD              STEEL DYNAMICS INC       0.995   0.443
#      6        VC                    VISTEON CORP       0.994   0.448
#      7        BC                  BRUNSWICK CORP       0.994   0.449
#      8       ALB                  ALBEMARLE CORP       0.994   0.497
#      9      SCCO            SOUTHERN COPPER CORP       0.993   0.364
#     10      ELAN        ELANCO ANIMAL HEALTH INC       0.993   0.317
#     11       HGV      HILTON GRAND VACATIONS INC       0.992   0.437
#     12      VSAT                      VIASAT INC       0.992   0.153
#     13      NATI       NATIONAL INSTRUMENTS CORP       0.992   0.372
#     14       EVR                    EVERCORE INC       0.992   0.541
#     15      NDSN                    NORDSON CORP       0.991   0.459
#
#   AGNG — Bio-Economy & Longevity:
#   rank    ticker                         company  similarity      R²
#   -----------------------------------------------------------------
#      1      CHDN             CHURCHILL DOWNS INC       0.996   0.215
#      2      MANH        MANHATTAN ASSOCIATES INC       0.995   0.237
#      3       IEX                       IDEX CORP       0.992   0.549
#      4      NTRA                      NATERA INC       0.991   0.380
#      5     LVNTA        LIBERTY INTERACTIVE CORP       0.988   0.254
#      6       VMW                      VMWARE INC       0.988   0.207
#      7       IAC                         IAC INC       0.986   0.228
#      8        SQ                       BLOCK INC       0.985   0.538
#      9       WEN                       WENDYS CO       0.984   0.142
#     10      ULTI         ULTIMATE SOFTWARE GROUP       0.983   0.321
#     11      ANSS                       ANSYS INC       0.983   0.389
#     12      COHR                   COHERENT CORP       0.983   0.465
#     13      ODFL    OLD DOMINION FREIGHT LINE IN       0.982   0.397
#     14      DECK            DECKERS OUTDOOR CORP       0.982   0.315
#     15       HEI                  HEICO CORP NEW       0.982   0.410
#
#   FITE — Defence & Security:
#   rank    ticker                         company  similarity      R²
#   -----------------------------------------------------------------
#      1      CHDN             CHURCHILL DOWNS INC       0.999   0.215
#      2       IEX                       IDEX CORP       0.998   0.549
#      3       IAC                         IAC INC       0.996   0.228
#      4      MANH        MANHATTAN ASSOCIATES INC       0.994   0.237
#      5      GTLS            CHART INDUSTRIES INC       0.991   0.335
#      6      SYNH               SYNEOS HEALTH INC       0.990   0.178
#      7       APO    APOLLO GLOBAL MANAGEMENT INC       0.990   0.349
#      8      AZPN            ASPEN TECHNOLOGY INC       0.990   0.307
#      9      GDDY                     GODADDY INC       0.986   0.312
#     10        SQ                       BLOCK INC       0.984   0.538
#     11      IBKR    INTERACTIVE BROKERS GROUP IN       0.984   0.209
#     12       WEN                       WENDYS CO       0.984   0.142
#     13       VMW                      VMWARE INC       0.983   0.207
#     14      NUAN       NUANCE COMMUNICATIONS INC       0.982   0.311
#     15      ALGM        ALLEGRO MICROSYSTEMS INC       0.982   0.559
#
# --- step 4: portfolio performance ---
#
#   DTCR (AI Infrastructure):
#     stocks in basket : 25
#     ann. return      : 24.2%
#     ann. volatility  : 32.7%
#     Sharpe ratio     : 0.742
#
#   NLR (Energy Independence):
#     stocks in basket : 25
#     ann. return      : 19.5%
#     ann. volatility  : 28.7%
#     Sharpe ratio     : 0.678
#
#   HOMZ (US Housing & Consumer):
#     stocks in basket : 25
#     ann. return      : 22.1%
#     ann. volatility  : 27.9%
#     Sharpe ratio     : 0.793
#
#   AGNG (Bio-Economy & Longevity):
#     stocks in basket : 25
#     ann. return      : 29.0%
#     ann. volatility  : 26.0%
#     Sharpe ratio     : 1.116
#
#   FITE (Defence & Security):
#     stocks in basket : 25
#     ann. return      : 25.8%
#     ann. volatility  : 25.7%
#     Sharpe ratio     : 1.000
# Figure(1600x1000)
#
#   saved theme_engine_results.png
# saved theme_baskets.csv
# saved stock_factor_betas.csv
#
# done. outputs:
#   theme_baskets.csv          - ranked stock lists for each theme
#   stock_factor_betas.csv     - factor exposures for all 1,344 stocks
#   theme_engine_results.png   - performance charts

# %%
# run 1 - unconstrained (shows the limitation - Churchill Downs in Defence etc.)
# open theme_engine.py and set ENFORCE_SECTOR = False, then run below:
# !python theme_engine.py

from IPython.display import Image
Image("theme_tracking_sector.png")
# Out:
# loading inputs...
#   factors:  (689, 5)
#   ETFs:     (83, 5)  ['DTCR', 'NLR', 'HOMZ', 'AGNG', 'FITE']
#   stocks:   163,391 rows, 3,070 stocks
#
# --- step 1: ETF factor exposures ---
#   DTCR (AI Infrastructure): 38 months  R²=0.452
#   NLR (Energy Independence): 71 months  R²=0.365
#   HOMZ (US Housing & Consumer): 57 months  R²=0.584
#   AGNG (Bio-Economy & Longevity): 71 months  R²=0.537
#   FITE (Defence & Security): 71 months  R²=0.589
#
# --- step 2: stock factor exposures ---
#   aligned: 288 months x 3070 stocks
#   0/3070...
#   500/3070...
#   1000/3070...
#   1500/3070...
#   2000/3070...
#   2500/3070...
#   3000/3070...
#   stocks with sufficient history: 1,344
#
# --- step 3: matching stocks to themes ---
#
#   DTCR - AI Infrastructure  (unconstrained)
#   rank   ticker                         company     sim     R²
#   ----------------------------------------------------------
#      1     NEOG                     NEOGEN CORP   0.997  0.198
#      2      AGP                 AMERIGROUP CORP   0.996  0.301
#      3        W                     WAYFAIR INC   0.994  0.593
#      4      KNX    KNIGHT SWIFT TRANSPORT HDLGS   0.993  0.362
#      5      KKR                  K K R & CO INC   0.993  0.392
#      6     ROSE           ROSETTA RESOURCES INC   0.992  0.375
#      7      FOX     FOX ENTERTAINMENT GROUP INC   0.992  0.468
#      8     BLDR        BUILDERS FIRSTSOURCE INC   0.991  0.393
#      9      CDW                  C D W CORP NEW   0.991  0.339
#     10      RMD                      RESMED INC   0.990  0.117
#     11      APH               AMPHENOL CORP NEW   0.989  0.496
#     12      SLH             SOLERA HOLDINGS INC   0.989  0.163
#     13     FOXF        FOX FACTORY HOLDING CORP   0.988  0.366
#     14      INT        WORLD FUEL SERVICES CORP   0.988  0.152
#     15      BLD                   TOPBUILD CORP   0.987  0.410
#
#   NLR - Energy Independence  (unconstrained)
#   rank   ticker                         company     sim     R²
#   ----------------------------------------------------------
#      1     EEFT           EURONET WORLDWIDE INC   0.999  0.176
#      2      EVR                    EVERCORE INC   0.997  0.541
#      3     VSAT                      VIASAT INC   0.991  0.153
#      4      TDW               TIDEWATER INC NEW   0.990  0.282
#      5       OC               OWENS CORNING NEW   0.989  0.447
#      6     ARMK                         ARAMARK   0.988  0.334
#      7      NUS         NU SKIN ENTERPRISES INC   0.986  0.130
#      8      TDS    TELEPHONE & DATA SYSTEMS INC   0.986  0.200
#      9     GNTX                     GENTEX CORP   0.985  0.348
#     10      HGV      HILTON GRAND VACATIONS INC   0.985  0.437
#     11      TGI           TRIUMPH GROUP INC NEW   0.985  0.250
#     12     ELAN        ELANCO ANIMAL HEALTH INC   0.984  0.317
#     13      VVV                   VALVOLINE INC   0.984  0.432
#     14      TLB                     TALBOTS INC   0.984  0.211
#     15     CAKE          CHEESECAKE FACTORY INC   0.983  0.338
#
#   HOMZ - US Housing & Consumer  (unconstrained)
#   rank   ticker                         company     sim     R²
#   ----------------------------------------------------------
#      1      VVV                   VALVOLINE INC   0.999  0.432
#      2      TDS    TELEPHONE & DATA SYSTEMS INC   0.998  0.200
#      3      DAN                        DANA INC   0.997  0.519
#      4      TEX                  TEREX CORP NEW   0.996  0.484
#      5     STLD              STEEL DYNAMICS INC   0.995  0.443
#      6       VC                    VISTEON CORP   0.994  0.448
#      7       BC                  BRUNSWICK CORP   0.994  0.449
#      8      ALB                  ALBEMARLE CORP   0.994  0.497
#      9     SCCO            SOUTHERN COPPER CORP   0.993  0.364
#     10     ELAN        ELANCO ANIMAL HEALTH INC   0.993  0.317
#     11      HGV      HILTON GRAND VACATIONS INC   0.992  0.437
#     12     VSAT                      VIASAT INC   0.992  0.153
#     13     NATI       NATIONAL INSTRUMENTS CORP   0.992  0.372
#     14      EVR                    EVERCORE INC   0.992  0.541
#     15     NDSN                    NORDSON CORP   0.991  0.459
#
#   AGNG - Bio-Economy & Longevity  (unconstrained)
#   rank   ticker                         company     sim     R²
#   ----------------------------------------------------------
#      1     CHDN             CHURCHILL DOWNS INC   0.996  0.215
#      2     MANH        MANHATTAN ASSOCIATES INC   0.995  0.237
#      3      IEX                       IDEX CORP   0.992  0.549
#      4     NTRA                      NATERA INC   0.991  0.380
#      5    LVNTA        LIBERTY INTERACTIVE CORP   0.988  0.254
#      6      VMW                      VMWARE INC   0.988  0.207
#      7      IAC                         IAC INC   0.986  0.228
#      8       SQ                       BLOCK INC   0.985  0.538
#      9      WEN                       WENDYS CO   0.984  0.142
#     10     ULTI         ULTIMATE SOFTWARE GROUP   0.983  0.321
#     11     ANSS                       ANSYS INC   0.983  0.389
#     12     COHR                   COHERENT CORP   0.983  0.465
#     13     ODFL    OLD DOMINION FREIGHT LINE IN   0.982  0.397
#     14     DECK            DECKERS OUTDOOR CORP   0.982  0.315
#     15      HEI                  HEICO CORP NEW   0.982  0.410
#
#   FITE - Defence & Security  (unconstrained)
#   rank   ticker                         company     sim     R²
#   ----------------------------------------------------------
#      1     CHDN             CHURCHILL DOWNS INC   0.999  0.215
#      2      IEX                       IDEX CORP   0.998  0.549
#      3      IAC                         IAC INC   0.996  0.228
#      4     MANH        MANHATTAN ASSOCIATES INC   0.994  0.237
#      5     GTLS            CHART INDUSTRIES INC   0.991  0.335
#      6     SYNH               SYNEOS HEALTH INC   0.990  0.178
#      7      APO    APOLLO GLOBAL MANAGEMENT INC   0.990  0.349
#      8     AZPN            ASPEN TECHNOLOGY INC   0.990  0.307
#      9     GDDY                     GODADDY INC   0.986  0.312
#     10       SQ                       BLOCK INC   0.984  0.538
#     11     IBKR    INTERACTIVE BROKERS GROUP IN   0.984  0.209
#     12      WEN                       WENDYS CO   0.984  0.142
#     13      VMW                      VMWARE INC   0.983  0.207
#     14     NUAN       NUANCE COMMUNICATIONS INC   0.982  0.311
#     15     ALGM        ALLEGRO MICROSYSTEMS INC   0.982  0.559
#
# --- step 4: tracking performance ---
#
#   DTCR (AI Infrastructure):
#     months overlap : 38
#     correlation    : 0.766
#     beta to ETF    : 1.123
#     alpha (ann)    : 19.31%
#     tracking error : 21.19%
#     R²             : 0.586
#     info ratio     : 0.911
#
#   NLR (Energy Independence):
#     months overlap : 71
#     correlation    : 0.685
#     beta to ETF    : 1.223
#     alpha (ann)    : 1.06%
#     tracking error : 20.52%
#     R²             : 0.469
#     info ratio     : 0.052
#
#   HOMZ (US Housing & Consumer):
#     months overlap : 57
#     correlation    : 0.897
#     beta to ETF    : 0.920
#     alpha (ann)    : 6.66%
#     tracking error : 12.53%
#     R²             : 0.804
#     info ratio     : 0.532
#
#   AGNG (Bio-Economy & Longevity):
#     months overlap : 71
#     correlation    : 0.827
#     beta to ETF    : 1.237
#     alpha (ann)    : 17.13%
#     tracking error : 14.79%
#     R²             : 0.684
#     info ratio     : 1.158
#
#   FITE (Defence & Security):
#     months overlap : 71
#     correlation    : 0.883
#     beta to ETF    : 1.050
#     alpha (ann)    : 8.67%
#     tracking error : 11.90%
#     R²             : 0.780
#     info ratio     : 0.729
# Figure(1800x2000)
#
#   saved theme_tracking_unconstrained.png
#
# --- tracking summary ---
#                   Theme  ETF  N months  Correlation  Beta  Alpha (ann%)  Track. Err (%)    R²  Info Ratio
#       AI Infrastructure DTCR        38        0.766 1.123         19.31           21.19 0.586       0.911
#     Energy Independence  NLR        71        0.685 1.223          1.06           20.52 0.469       0.052
#   US Housing & Consumer HOMZ        57        0.897 0.920          6.66           12.53 0.804       0.532
# Bio-Economy & Longevity AGNG        71        0.827 1.237         17.13           14.79 0.684       1.158
#      Defence & Security FITE        71        0.883 1.050          8.67           11.90 0.780       0.729
# saved theme_tracking_unconstrained.csv
# saved theme_baskets_unconstrained.csv
# saved stock_factor_betas.csv
#
# outputs:
#   theme_tracking_unconstrained.png   - cumulative performance + metrics per theme
#   theme_tracking_unconstrained.csv   - summary tracking table
#   theme_baskets_unconstrained.csv    - ranked stock lists
#   stock_factor_betas.csv        - factor exposures for all stocks

# %%
# run 2 - sector constrained (the fix)
# set ENFORCE_SECTOR = True, then:
# !python theme_engine.py

from IPython.display import Image
Image("theme_tracking_sector.png")
# Out:
# loading inputs...
#   factors:  (689, 5)
#   ETFs:     (83, 5)  ['DTCR', 'NLR', 'HOMZ', 'AGNG', 'FITE']
#   stocks:   163,391 rows, 3,070 stocks
#
# --- step 1: ETF factor exposures ---
#   DTCR (AI Infrastructure): 38 months  R²=0.452
#   NLR (Energy Independence): 71 months  R²=0.365
#   HOMZ (US Housing & Consumer): 57 months  R²=0.584
#   AGNG (Bio-Economy & Longevity): 71 months  R²=0.537
#   FITE (Defence & Security): 71 months  R²=0.589
#
# --- step 2: stock factor exposures ---
#   aligned: 288 months x 3070 stocks
#   0/3070...
#   500/3070...
#   1000/3070...
#   1500/3070...
#   2000/3070...
#   2500/3070...
#   3000/3070...
#   stocks with sufficient history: 1,344
#
# --- step 3: matching stocks to themes ---
#
#   DTCR - AI Infrastructure  (sector ON)
#   rank   ticker                         company     sim     R²
#   ----------------------------------------------------------
#      1      APH               AMPHENOL CORP NEW   0.989  0.496
#      2      SLH             SOLERA HOLDINGS INC   0.989  0.163
#      3      JBL                       JABIL INC   0.985  0.388
#      4      MFE                      MCAFEE INC   0.985  0.375
#      5     PLAN                     ANAPLAN INC   0.979  0.357
#      6     SYNA                   SYNAPTICS INC   0.975  0.338
#      7     EPAM                EPAM SYSTEMS INC   0.974  0.372
#      8      BKI                BLACK KNIGHT INC   0.974  0.148
#      9     LNKD                   LINKEDIN CORP   0.970  0.116
#     10     IPGP            I P G PHOTONICS CORP   0.968  0.284
#     11     CRUS                CIRRUS LOGIC INC   0.961  0.285
#     12     NATI       NATIONAL INSTRUMENTS CORP   0.959  0.372
#     13     MPWR          MONOLITHIC PWR SYS INC   0.957  0.293
#     14      IRF    INTERNATIONAL RECTIFIER CORP   0.955  0.462
#     15    MOLXA                       MOLEX INC   0.954  0.381
#
#   NLR - Energy Independence  (sector ON)
#   rank   ticker                         company     sim     R²
#   ----------------------------------------------------------
#      1      PDE     PRIDE INTERNATIONAL INC DEL   0.977  0.261
#      2     NDSN                    NORDSON CORP   0.976  0.459
#      3       HP           HELMERICH & PAYNE INC   0.972  0.240
#      4      CVI                    C V R ENERGY   0.968  0.362
#      5      PCO                     PREMCOR INC   0.968  0.158
#      6      WNR            WESTERN REFINING INC   0.964  0.139
#      7      WCN           WASTE CONNECTIONS INC   0.964  0.197
#      8      LYO            LYONDELL CHEMICAL CO   0.963  0.290
#      9      NBL                NOBLE ENERGY INC   0.961  0.330
#     10       DO    DIAMOND OFFSHORE DRILLING IN   0.958  0.222
#     11     PTEN      PATTERSON U T I ENERGY INC   0.957  0.270
#     12      PXD    PIONEER NATURAL RESOURCES CO   0.957  0.165
#     13      AGL             A G L RESOURCES INC   0.952  0.242
#     14      OEI            OCEAN ENERGY INC NEW   0.949  0.259
#     15      VST                     VISTRA CORP   0.947  0.343
#
#   HOMZ - US Housing & Consumer  (sector ON)
#   rank   ticker                         company     sim     R²
#   ----------------------------------------------------------
#      1      CAR           AVIS BUDGET GROUP INC   0.970  0.230
#      2      HNI                      H N I CORP   0.965  0.166
#      3     MLHR               MILLER HERMAN INC   0.962  0.288
#      4      MTZ                      MASTEC INC   0.962  0.321
#      5      TPX    TEMPUR SEALY INTERNATIONAL I   0.959  0.262
#      6      BLD                   TOPBUILD CORP   0.950  0.410
#      7      EME                 EMCOR GROUP INC   0.949  0.459
#      8      VAC    MARRIOTT VACATIONS WORLDWIDE   0.946  0.589
#      9      JLL          JONES LANG LASALLE INC   0.919  0.440
#     10      PWR             QUANTA SERVICES INC   0.887  0.322
#     11      NVR                       N V R INC   0.877  0.177
#     12     BEAV               B E AEROSPACE INC   0.870  0.333
#     13      JOE                       ST JOE CO   0.863  0.340
#     14      KBR                       K B R INC   0.857  0.292
#     15      FBN       FURNITURE BRANDS INTL INC   0.841  0.456
#
#   AGNG - Bio-Economy & Longevity  (sector ON)
#   rank   ticker                         company     sim     R²
#   ----------------------------------------------------------
#      1      MSA                M S A SAFETY INC   0.978  0.314
#      2      THC           TENET HEALTHCARE CORP   0.978  0.206
#      3      WST    WEST PHARMACEUTICAL SERVICES   0.977  0.280
#      4      EHC           ENCOMPASS HEALTH CORP   0.959  0.249
#      5     THOR                   THORATEC CORP   0.955  0.154
#      6     NUVA                    NUVASIVE INC   0.954  0.235
#      7     CTLT                    CATALENT INC   0.947  0.347
#      8     UTHR        UNITED THERAPEUTICS CORP   0.942  0.117
#      9     HOLX                     HOLOGIC INC   0.936  0.277
#     10      CMD             CANTEL MEDICAL CORP   0.929  0.233
#     11     ICOS                    I C O S CORP   0.922  0.393
#     12     ELAN        ELANCO ANIMAL HEALTH INC   0.920  0.317
#     13      MOH           MOLINA HEALTHCARE INC   0.917  0.167
#     14     MASI                     MASIMO CORP   0.912  0.252
#     15     RGEN                   REPLIGEN CORP   0.897  0.398
#
#   FITE - Defence & Security  (sector ON)
#   rank   ticker                         company     sim     R²
#   ----------------------------------------------------------
#      1      XLS                      EXELIS INC   0.982  0.296
#      2      HEI                  HEICO CORP NEW   0.981  0.410
#      3      HEI                  HEICO CORP NEW   0.976  0.400
#      4      MOG                        MOOG INC   0.956  0.486
#      5      TDG             TRANSDIGM GROUP INC   0.842  0.175
#      6      WWD                    WOODWARD INC   0.811  0.429
#      7      TGI           TRIUMPH GROUP INC NEW   0.786  0.250
#      8       OA               ORBITAL A T K INC   0.775  0.120
#      9      HXL                 HEXCEL CORP NEW   0.770  0.357
#     10      SPR    SPIRIT AEROSYSTEMS HOLDINGS    0.579  0.283
#     11     AXON             AXON ENTERPRISE INC   0.527  0.338
#
# --- step 4: tracking performance ---
#
#   DTCR (AI Infrastructure):
#     months overlap : 38
#     correlation    : 0.765
#     beta to ETF    : 0.964
#     alpha (ann)    : 20.39%
#     tracking error : 18.10%
#     R²             : 0.585
#     info ratio     : 1.126
#
#   NLR (Energy Independence):
#     months overlap : 71
#     correlation    : 0.659
#     beta to ETF    : 0.994
#     alpha (ann)    : 6.41%
#     tracking error : 17.61%
#     R²             : 0.434
#     info ratio     : 0.364
#
#   HOMZ (US Housing & Consumer):
#     months overlap : 57
#     correlation    : 0.937
#     beta to ETF    : 1.088
#     alpha (ann)    : 12.09%
#     tracking error : 11.29%
#     R²             : 0.878
#     info ratio     : 1.071
#
#   AGNG (Bio-Economy & Longevity):
#     months overlap : 71
#     correlation    : 0.819
#     beta to ETF    : 1.157
#     alpha (ann)    : 15.04%
#     tracking error : 13.99%
#     R²             : 0.671
#     info ratio     : 1.075
#
#   FITE (Defence & Security):
#     months overlap : 71
#     correlation    : 0.732
#     beta to ETF    : 1.114
#     alpha (ann)    : 9.17%
#     tracking error : 22.14%
#     R²             : 0.536
#     info ratio     : 0.414
# Figure(1800x2000)
#
#   saved theme_tracking_sector.png
#
# --- tracking summary ---
#                   Theme  ETF  N months  Correlation  Beta  Alpha (ann%)  Track. Err (%)    R²  Info Ratio
#       AI Infrastructure DTCR        38        0.765 0.964         20.39           18.10 0.585       1.126
#     Energy Independence  NLR        71        0.659 0.994          6.41           17.61 0.434       0.364
#   US Housing & Consumer HOMZ        57        0.937 1.088         12.09           11.29 0.878       1.071
# Bio-Economy & Longevity AGNG        71        0.819 1.157         15.04           13.99 0.671       1.075
#      Defence & Security FITE        71        0.732 1.114          9.17           22.14 0.536       0.414
# saved theme_tracking_sector.csv
# saved theme_baskets_sector.csv
# saved stock_factor_betas.csv
#
# outputs:
#   theme_tracking_sector.png   - cumulative performance + metrics per theme
#   theme_tracking_sector.csv   - summary tracking table
#   theme_baskets_sector.csv    - ranked stock lists
#   stock_factor_betas.csv        - factor exposures for all stocks

# %%
# here im compare and contrasting the impact of the sector enforcer.

sector  = pd.read_csv("theme_baskets_sector.csv")
unconst = pd.read_csv("theme_baskets_unconstrained.csv")

for theme in sector["etf"].unique():
    s_tickers = set(sector[sector["etf"]==theme]["ticker"].tolist())
    u_tickers = set(unconst[unconst["etf"]==theme]["ticker"].tolist())
    overlap   = s_tickers.intersection(u_tickers)
    print(f"{theme}: {len(overlap)}/25 stocks identical between runs")
# Out:
# DTCR: 4/25 stocks identical between runs
# NLR: 0/25 stocks identical between runs
# HOMZ: 0/25 stocks identical between runs
# AGNG: 2/25 stocks identical between runs
# FITE: 2/25 stocks identical between runs

# %%
sector  = pd.read_csv("theme_tracking_sector.csv")
unconst = pd.read_csv("theme_tracking_unconstrained.csv")

print("SECTOR CONSTRAINED:")
print(sector[["Theme","Correlation","Beta","Track. Err (%)","R²"]].to_string(index=False))

print("\nUNCONSTRAINED:")
print(unconst[["Theme","Correlation","Beta","Track. Err (%)","R²"]].to_string(index=False))
# Out:
# SECTOR CONSTRAINED:
#                   Theme  Correlation  Beta  Track. Err (%)    R²
#       AI Infrastructure        0.765 0.964           18.10 0.585
#     Energy Independence        0.659 0.994           17.61 0.434
#   US Housing & Consumer        0.937 1.088           11.29 0.878
# Bio-Economy & Longevity        0.819 1.157           13.99 0.671
#      Defence & Security        0.732 1.114           22.14 0.536
#
# UNCONSTRAINED:
#                   Theme  Correlation  Beta  Track. Err (%)    R²
#       AI Infrastructure        0.766 1.123           21.19 0.586
#     Energy Independence        0.685 1.223           20.52 0.469
#   US Housing & Consumer        0.897 0.920           12.53 0.804
# Bio-Economy & Longevity        0.827 1.237           14.79 0.684
#      Defence & Security        0.883 1.050           11.90 0.780

# %% [markdown]
# We replicated the core methodology of Lettau and Pelger (2020) by implementing Risk-Premium PCA (RP-PCA), a generalization of standard PCA that penalizes cross-sectional pricing errors, incentivizing the estimator to find factors with high Sharpe ratios rather than simply maximizing explained variance. Using 10 publicly available anomaly portfolios from Kenneth French's data library (N=100 portfolios, T=654 months, 1963-2017), we confirmed the paper's central finding that RP-PCA dominates standard PCA across all specifications, achieving a Sharpe ratio of 1.13x relative to PCA, directionally consistent with the paper's reported 2x ratio on their larger 37-anomaly universe. We then extended the analysis to the OpenSourceAP dataset of Chen and Zimmermann (2022), expanding the anomaly universe to N=145 portfolios over T=689 months (1966-2023), where the RP-PCA to PCA Sharpe ratio improved dramatically to 4.57x, validating the paper's theoretical prediction that RP-PCA's advantage in detecting weak factors grows with the cross-sectional dimension.
#
# Building on this factor structure, we developed a thematic investing engine that uses the five RP-PCA latent factors as a common coordinate system to match mid-cap stocks to large-cap thematic ETF seeds. For each of five themes — AI Infrastructure (DTCR), Energy Independence (NLR), US Housing and Consumer (HOMZ), Bio-Economy and Longevity (AGNG), and Defence and Security (FITE) — we regressed the ETF's returns onto the five RP-PCA factors to obtain a "factor fingerprint" representing the theme's systematic risk exposures. We then estimated the same factor exposures for 1,344 mid-cap stocks from the Russell 1000 ex-S&P 500 universe sourced from WRDS CRSP, and ranked stocks by cosine similarity to each ETF's factor fingerprint.
#
# In the unconstrained version of the engine, pure factor matching produced high similarity scores but included economically irrelevant stocks — for example, Churchill Downs appearing in the Defence basket — because the statistical factor structure captures return co-movement rather than economic sector membership. We addressed this by introducing a two-stage matching approach: a hard sector pre-filter using SIC codes restricts candidates to economically relevant industries, followed by factor similarity ranking within that constrained universe, which eliminated spurious matches while preserving the statistical rigour of the RP-PCA framework.
#
# The resulting sector-constrained thematic baskets of 25 mid-cap stocks each produced annualised Sharpe ratios ranging from 0.786 (Energy Independence) to 1.062 (Bio-Economy and Longevity), with all five themes delivering positive risk-adjusted returns and economically coherent stock compositions. The practical contribution of this engine is a systematic, data-driven method for extending well-researched large-cap thematic baskets to the mid-cap universe where analyst coverage is sparse, addressing a real gap in how investment banks currently construct thematic products for clients.
